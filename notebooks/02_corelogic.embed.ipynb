# %% [markdown]
# # NC CoreLogic → Study Area Trim + QA/QC (R)
#
# Workflow Conversion from Python to R

# %%
library(readr)
library(dplyr)
library(sf)
library(stringr)
library(tidyr)

corelogic_csv <- params$corelogic_csv
parcels_gpkg  <- params$parcels_gpkg
output_csv    <- params$output_csv

stopifnot(file.exists(corelogic_csv))
stopifnot(file.exists(parcels_gpkg))

cat("CoreLogic CSV:", corelogic_csv, "\n")
# Out:
# CoreLogic CSV: /proj/mhinolab/projects/obstacles2/CRC_May_2025/Raw Data Inputs/Core Logic NC/statedf_NC_2024-11-05.csv
# Parcels GPKG : /proj/mhinolab/projects/obstacles2/MH_Output/parcels_study_area.gpkg
# Output CSV  : /proj/mhinolab/projects/obstacles2/MH_Output/cl.csv

# %%
cl <- readr::read_csv(
  corelogic_csv,
  col_types = cols(.default = col_character())
)

parcels <- sf::st_read(parcels_gpkg, quiet = TRUE)

stopifnot("cntyfips" %in% names(parcels))
stopifnot("FIPS CODE" %in% names(cl))

cat("CoreLogic rows:", nrow(cl), " cols:", ncol(cl), "\n")
# Out:
# CoreLogic rows: 5614526  cols: 232
# Parcels rows  : 4180148  cols: 16
